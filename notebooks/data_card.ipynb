# %% [markdown]
# # Data Card: dataset_id_96
#
# ## Dataset Description
# - **Name**: dataset_id_96
# - **Description**: Credit risk assessment dataset
# - **Creation Date**: Unknown
# - **Version**: 1.0
#
# ## Dataset Characteristics
# - **Number of Instances**: 100
# - **Number of Features**: 32
# - **Target Variable**: y (boolean)
#
# ## Features
# 1. checking_status (categorical)
# 2. duration (integer)
# 3. credit_history (categorical)
# 4. purpose (categorical)
# 5. credit_amount (float)
# 6. savings_status (categorical)
# 7. employment (categorical)
# 8. installment_commitment (integer)
# 9. personal_status (categorical)
# 10. other_parties (categorical)
# 11. residence_since (integer)
# 12. property_magnitude (categorical)
# 13. age (integer)
# 14. other_payment_plans (categorical)
# 15. housing (categorical)
# 16. existing_credits (integer)
# 17. job (categorical)
# 18. num_dependents (integer)
# 19. own_telephone (categorical)
# 20. foreign_worker (categorical)
# 21. health_status (categorical)
# 22. X_1 to X_10 (float): Additional numerical features
#
# ## Data Quality Metrics
# Haven't done yet
#
# ## Feature Descriptions
# - **checking_status**: Status of existing checking account
# - **credit_history**: Credit history of the applicant
# - **purpose**: Purpose of the credit
# - **savings_status**: Status of savings accounts/bonds
# - **employment**: Present employment since
# - **personal_status**: Sex & marital status
# - **other_parties**: Other debtors / guarantors
# - **property_magnitude**: Property (e.g. real estate)
# - **other_payment_plans**: Other installment plans
# - **housing**: Housing (own, rent, or free)
# - **job**: Job type
# - **foreign_worker**: Is the applicant a foreign worker?
# - **health_status**: Health status of the applicant
#
# ## Target Variable
# - **y**: Boolean indicating credit risk (True, False)
#
# ## Intended Use
# This dataset is intended for credit risk assessment. It can be used to train machine learning models to predict the likelihood of credit default.
#
# ## Ethical Considerations
# - Ensure fair and unbiased use of the data, particularly regarding protected attributes like personal status.
# - Be cautious of potential biases in the original data collection process.
# - Consider the implications of using this data for decision-making in financial contexts.
# - Users should be aware of potential privacy concerns when working with personal financial data.
#
# ## Known Limitations
# - The dataset is relatively small (100 instances in the example), which may limit its representativeness.
# - The categorical variable has imbalanced categories.
# - The additional numerical features (X_1 to X_10) lack clear descriptions of what they represent.
