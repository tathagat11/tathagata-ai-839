# %%
load_ext kedro.ipython
# Out:
# The kedro.ipython extension is already loaded. To reload it, use:
#   %reload_ext kedro.ipython

# %%
catalog
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# {'dataset_id_96': "kedro_datasets.pandas.csv_dataset.CSVDataset(filepath=PurePosixPath('/home/tathagat/workspace/projects/MLPE/tathagata-ai-839/tathagata-ai-839/data/hw03/dataset_id_96.csv'), "
#                   "protocol='file', load_args={}, save_args={'index': False})",
#  'parameters': "kedro.io.memory_dataset.MemoryDataset(data='<dict>')"}

# %%
df = catalog.load("dataset_id_96")
# Out:
#                     INFO     Loading data from dataset_id_96 (CSVDataset)...                    ]8;id=168774;file:///home/tathagat/workspace/projects/MLPE/tathagata-ai-839/.venv/lib/python3.10/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=143982;file:///home/tathagat/workspace/projects/MLPE/tathagata-ai-839/.venv/lib/python3.10/site-packages/kedro/io/data_catalog.py#537\537]8;;\

# %%
df.head()
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#   checking_status  duration                  credit_history  \
# 0     no checking         9                   existing paid
# 1        0<=X<200        18                   existing paid
# 2     no checking        12             no credits/all paid
# 3     no checking        15  critical/other existing credit
# 4        0<=X<200        15                   existing paid
#
#                purpose  credit_amount    savings_status employment  \
# 0             business         1449.0              <100     4<=X<7
# 1             business         1941.0            >=1000     1<=X<4
# 2  furniture/equipment         2759.0              <100        >=7
# 3  furniture/equipment         1520.0  no known savings        >=7
# 4             radio/tv         1444.0  no known savings         <1
#
# ...

# %%
df.dtypes
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# checking_status            object
# duration                    int64
# credit_history             object
# purpose                    object
# credit_amount             float64
# savings_status             object
# employment                 object
# installment_commitment      int64
# personal_status            object
# other_parties              object
# residence_since             int64
# property_magnitude         object
# age                         int64
# other_payment_plans        object
# housing                    object
# existing_credits            int64
# job                        object
# num_dependents              int64
# own_telephone              object
# foreign_worker             object
# health_status              object
# X_1                       float64
# X_2                       float64
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 32 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   checking_status         100 non-null    object
#  1   duration                100 non-null    int64
#  2   credit_history          100 non-null    object
#  3   purpose                 100 non-null    object
#  4   credit_amount           100 non-null    float64
#  5   savings_status          100 non-null    object
#  6   employment              100 non-null    object
#  7   installment_commitment  100 non-null    int64
#  8   personal_status         100 non-null    object
#  9   other_parties           100 non-null    object
#  10  residence_since         100 non-null    int64
#  11  property_magnitude      100 non-null    object
#  12  age                     100 non-null    int64
#  13  other_payment_plans     100 non-null    object
# ...

# %%
# Out:
# Class Distribution:
# y
# True     0.5125
# False    0.4875
# Name: proportion, dtype: float64
#
# Feature Importance (based on mutual information with target):
#                                feature  mutual_info_score
# 71                  health_status_good           0.325153
# 70                   health_status_bad           0.317116
# 8                                  X_2           0.207705
# 9                                  X_3           0.159861
# 18                  checking_status_<0           0.104322
# ..                                 ...                ...
# 6                       num_dependents           0.000000
# 12                                 X_6           0.000000
# 45  personal_status_female div/dep/mar           0.000000
# 23   credit_history_delayed previously           0.000000
# 17            checking_status_0<=X<200           0.000000
#
# [72 rows x 2 columns]
#
# Correlation with Target (for numeric features):
# ...
